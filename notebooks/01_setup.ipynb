# %% [markdown]
# # Phoenix AI X — Setup
#
# Colab-ready environment setup. This notebook deliberately performs no trading activity.

# %%
# TODO: install a pinned Phoenix AI X research profile and validate the runtime.

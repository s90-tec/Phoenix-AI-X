# %% [markdown]
# # Phoenix AI X — Data Collection
#
# Template for approved, licensed data ingestion with provenance and validation.

# %%
# TODO: define a source contract; never embed credentials or fetch unlicensed data.

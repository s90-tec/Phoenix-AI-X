# %% [markdown]
# # Phoenix AI X — Model Training
#
# Template for tracked, reproducible model-training experiments.

# %%
# TODO: configure MLflow, seed all sources of randomness, and train a research model.

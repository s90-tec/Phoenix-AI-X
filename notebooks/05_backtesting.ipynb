# %% [markdown]
# # Phoenix AI X — Backtesting
#
# Template for evaluation design; no simulator or trading strategy is implemented yet.

# %%
# TODO: specify chronology-safe validation and transaction-cost assumptions.

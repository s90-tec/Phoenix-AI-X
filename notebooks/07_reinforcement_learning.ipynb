# %% [markdown]
# # Phoenix AI X — Reinforcement Learning
#
# Template for constrained RL research in a synthetic environment.

# %%
# TODO: define a synthetic environment, reward policy, and safety constraints.
